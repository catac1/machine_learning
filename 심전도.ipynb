# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# ...   ...
# 4993  0.0
# 4994  0.0
# 4995  0.0
# 4996  0.0
# 4997  0.0
#
# [4998 rows x 1 columns]

# %%
data = df[ df.columns[:-1]].values
label = df[140].values

data.shape, label.shape
# Out:
# ((4998, 140), (4998,))

# %%
# 훈련, 테스트 나누기
from sklearn.model_selection import train_test_split

x_split = int(len(data) * 0.8)
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=123)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3998, 140), (1000, 140), (3998,), (1000,))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

x_train_scaled.shape, x_test_scaled.shape
# Out:
# ((3998, 140), (1000, 140))

# %%
# y_train에서 0이면 false 1이면 true로 변경

y_train_label = y_train.astype('bool')
y_train_label[:3]
# Out:
# array([ True, False, False])

# %%
x_train_normal = x_train_scaled[y_train_label] # true 추출
x_train_anomalous = x_train_scaled[~y_train_label] # false 추출

x_train_normal.shape, x_train_anomalous.shape
# Out:
# ((2323, 140), (1675, 140))

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 6))
for i in range(5):
    plt.subplot(2, 5, (i + 1))
    plt.plot(np.arange(140), x_train_normal[i])
    plt.grid()
    
    plt.subplot(2, 5, (i + 1 + 5))
    plt.plot(np.arange(140), x_train_anomalous[i])
    plt.grid()

plt.show()

# %%
y_test_label = y_test.astype('bool')
x_test_normal = x_test_scaled[y_test_label] # true 추출
x_test_anomalous = x_test_scaled[~y_test_label] # false 추출

x_train_normal.shape, x_train_anomalous.shape, x_test_normal.shape, x_test_anomalous.shape
# Out:
# ((2323, 140), (1675, 140), (596, 140), (404, 140))

# %%
import tensorflow as tf
from tensorflow.keras import layers

encoder_input = layers.Input(shape=(140,))
x = layers.Dense(units=32, activation="elu")(encoder_input)
x = layers.Dense(units=16, activation="elu")(x)
encoder_output = layers.Dense(units=8, activation="elu")(x)

encoder = tf.keras.models.Model(encoder_input, encoder_output)
encoder.summary()
# Out:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_25 (InputLayer)     │ (None, 140)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 32)             │         4,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 8)              │           136 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,176 (20.22 KB)
#  Trainable params: 5,176 (20.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
decoder_input = layers.Input(shape=(8,))
x = layers.Dense(units=16, activation="elu")(decoder_input)
x = layers.Dense(units=32, activation="elu")(x)
decoder_output = layers.Dense(units=140, activation="sigmoid")(x)
decoder = tf.keras.models.Model(decoder_input, decoder_output)
decoder.summary()
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_26 (InputLayer)     │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 140)            │         4,620 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,308 (20.73 KB)
#  Trainable params: 5,308 (20.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
auto_input = layers.Input(shape=(140,))
encoded = encoder(auto_input)
decoded = decoder(encoded)
autoencoder = tf.keras.models.Model(auto_input, decoded)
autoencoder.summary()
# Out:
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_29 (InputLayer)     │ (None, 140)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_20 (Functional)      │ (None, 8)              │         5,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_21 (Functional)      │ (None, 140)            │         5,308 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,484 (40.95 KB)
#  Trainable params: 10,484 (40.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %%
autoencoder.fit(
    x_train_normal, 
    x_train_normal, 
    epochs=100, 
    verbose=2, 
    validation_data=(x_test_normal, x_test_normal)
)
# Out:
# Epoch 1/100
# 73/73 - 2s - 21ms/step - loss: 0.0020 - mae: 0.0308 - val_loss: 0.0017 - val_mae: 0.0274
# Epoch 2/100
# 73/73 - 0s - 2ms/step - loss: 0.0014 - mae: 0.0251 - val_loss: 0.0014 - val_mae: 0.0250
# Epoch 86/100
# 73/73 - 0s - 2ms/step - loss: 5.4812e-04 - mae: 0.0158 - val_loss: 7.1493e-04 - val_mae: 0.0171
# Epoch 87/100
# 73/73 - 0s - 2ms/step - loss: 5.4783e-04 - mae: 0.0158 - val_loss: 7.1372e-04 - val_mae: 0.0170
# Epoch 88/100
# 73/73 - 0s - 2ms/step - loss: 5.4562e-04 - mae: 0.0158 - val_loss: 7.0991e-04 - val_mae: 0.0170
# Epoch 89/100
# 73/73 - 0s - 2ms/step - loss: 5.4365e-04 - mae: 0.0157 - val_loss: 7.1114e-04 - val_mae: 0.0169
# Epoch 90/100
# 73/73 - 0s - 4ms/step - loss: 5.4486e-04 - mae: 0.0158 - val_loss: 7.1417e-04 - val_mae: 0.0171
# Epoch 91/100
# 73/73 - 0s - 2ms/step - loss: 5.4551e-04 - mae: 0.0158 - val_loss: 7.1321e-04 - val_mae: 0.0171
# Epoch 92/100
# 73/73 - 0s - 2ms/step - loss: 5.4433e-04 - mae: 0.0158 - val_loss: 7.0694e-04 - val_mae: 0.0170
# Epoch 93/100
# 73/73 - 0s - 3ms/step - loss: 5.4330e-04 - mae: 0.0158 - val_loss: 7.1539e-04 - val_mae: 0.0171
# Epoch 94/100
# 73/73 - 0s - 2ms/step - loss: 5.4133e-04 - mae: 0.0157 - val_loss: 7.0808e-04 - val_mae: 0.0170
# Epoch 95/100
# 73/73 - 0s - 2ms/step - loss: 5.3928e-04 - mae: 0.0157 - val_loss: 7.0254e-04 - val_mae: 0.0168
# Epoch 96/100
# 73/73 - 0s - 2ms/step - loss: 5.4154e-04 - mae: 0.0158 - val_loss: 7.0697e-04 - val_mae: 0.0170
# Epoch 97/100
# 73/73 - 0s - 2ms/step - loss: 5.4013e-04 - mae: 0.0157 - val_loss: 7.1337e-04 - val_mae: 0.0171
# Epoch 98/100
# 73/73 - 0s - 2ms/step - loss: 5.3928e-04 - mae: 0.0157 - val_loss: 7.0901e-04 - val_mae: 0.0171
# Epoch 99/100
# 73/73 - 0s - 2ms/step - loss: 5.3732e-04 - mae: 0.0157 - val_loss: 7.0577e-04 - val_mae: 0.0170
# Epoch 100/100
# 73/73 - 0s - 2ms/step - loss: 5.3594e-04 - mae: 0.0157 - val_loss: 7.0270e-04 - val_mae: 0.0168

# %%
decoded_data = autoencoder.predict(x_test_normal)

plt.figure(figsize=(10, 3))
plt.subplot(1, 2, 1)
plt.plot(x_test_normal[0])
plt.plot(decoded_data[0])
plt.fill_between(np.arange(140), decoded_data[0], x_test_normal[0], color="lightcoral")

train_loss = tf.keras.losses.mae(decoded_data, x_test_normal)
plt.subplot(1, 2, 2)
plt.hist(train_loss, bins=50)
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
decoded_data = autoencoder.predict(x_test_anomalous)

plt.figure(figsize=(10, 3))
plt.subplot(1, 2, 1)
plt.plot(x_test_anomalous[0])
plt.plot(decoded_data[0])
plt.fill_between(np.arange(140), decoded_data[0], x_test_anomalous[0], color="lightcoral")

train_loss = tf.keras.losses.mae(decoded_data, x_test_anomalous)
plt.subplot(1, 2, 2)
plt.hist(train_loss, bins=50)
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
