# %%
# 라이브러리 설치확인
import selenium
import webdriver_manager

selenium.__version__, webdriver_manager.__version__
# Out:
# ('4.44.0', '4.1.0')

# %%
! pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
import os
import urllib
os.path.basename(urllib.parse.urlparse('9788925588735.jpg?v=494186').path)
# Out:
# '9788925588735.jpg'

# %%
from IPython.display import Image, display
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
import os
from urllib.parse import urlparse

options = Options()

options.add_argument("--headless")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
options.add_argument(f"user-agent={user_agent}")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--lang=ko-KR,ko")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

driver = webdriver.Chrome(service=Service("./driver/chromedriver.exe"), options=options)

try:
    url = 'https://store.kyobobook.co.kr/bestseller/online/daily'
    driver.get(url)
    time.sleep(1.5) # unit: seconds
    for i in range(1, 3): # advertisement split index ol tag
        for j in range(1, 11): # index of the li elements
            title_xpath = f'/html/body/div[2]/main/section/div/div/section/ol[{i}]/li[{j}]/div/div[2]/div[2]/a'
            image_xpath = f'/html/body/div[2]/main/section/div/div/section/ol[{i}]/li[{j}]/div/div[2]/div[1]/a/div/img'

            title_atag = driver.find_element(By.XPATH, title_xpath)
            title_imgtag = driver.find_element(By.XPATH, image_xpath)
            src = title_imgtag.get_attribute("src")
            
            print(title_atag.text)
            print(src)
            
            # img = Image(url=src)
            # display(img)

            # src에서 파일명만 추출
            parsed = urlparse(src)
            filename = os.path.basename(parsed.path)
            print(filename)

            response = requests.get(src)
            if response.status_code == 200:
                with open(f'./image/{filename}', 'wb') as f:
                    f.write(response.content)
except Exception as e:
    print(e)
finally:
    # pass
    driver.quit()
# Out:
# 프로젝트 헤일메리
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9788925588735.jpg?v=494186
# 9788925588735.jpg
# 번뇌를 종료합니다
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791194415343.jpg?v=494186
# 9791194415343.jpg
# 품격 있는 대화를 위한 지식 브리핑
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791124038413.jpg?v=494186
# 9791124038413.jpg
# 예약판매웨딩 피플
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791124038437.jpg?v=494186
# 9791124038437.jpg
# 바다에서 온 소년
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791124038338.jpg?v=494186
# 9791124038338.jpg
# 내면 근력
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791155819227.jpg?v=494186
# 9791155819227.jpg
# 안녕이라 그랬어
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791141602376.jpg?v=494186
# 9791141602376.jpg
# 이더리움 없는 미래는 없다
# https://contents.kyobobook.co.kr/sih/fit-in/300x0/pdt/9791193869437.jpg?v=494186
# 9791193869437.jpg
# 흔한남매 22
# ...

# %%
from IPython.display import Image, display
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
import os
from urllib.parse import urlparse
import re

options = Options()

options.add_argument("--headless")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
options.add_argument(f"user-agent={user_agent}")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--lang=ko-KR,ko")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

driver = webdriver.Chrome(service=Service("./driver/chromedriver.exe"), options=options)

try:
    url = "https://shop.teacherville.co.kr/goods/best"
    driver.get(url)
    time.sleep(1)
    for i in range(1, 101):
        xpath = f'//*[@id="goods_best_common"]/li[{i}]/div[1]'
        div = driver.find_element(By.XPATH, xpath)
        style = div.get_attribute('style')
        match = re.search(r'url\(["\']?(?P<path>[^"\')]+)["\']?\)', style)
        if match:
            src = f'https://shop.teacherville.co.kr/{match.group("path")}'
            parsed = urlparse(src)
            filename = os.path.basename(parsed.path)
            print(filename)

            response = requests.get(src)
            if response.status_code == 200:
                with open(f'./image/{filename}', 'wb') as f:
                    f.write(response.content)
except Exception as e:
    print(e)
finally:
    driver.quit()
# Out:
# 1210424_tmp_d41d8cd98f00b204e9800998ecf8427e9455list2.jpg
# 983882_tmp_d41d8cd98f00b204e9800998ecf8427e9834list2.jpg
# 20180828103939_573990_378.jpg
# 1179872_tmp_d41d8cd98f00b204e9800998ecf8427e1278list2.jpg
# 1182254_tmp_d41d8cd98f00b204e9800998ecf8427e9705list2.jpg
# _tmp_d41d8cd98f00b204e9800998ecf8427e0241list2.JPG
# _tmp_d41d8cd98f00b204e9800998ecf8427e7427list2.jpg
# _tmp_d41d8cd98f00b204e9800998ecf8427e7162list2.jpg
# 1169528_tmp_d41d8cd98f00b204e9800998ecf8427e3923list2.png
# 1142679_tmp_d41d8cd98f00b204e9800998ecf8427e7584list2.jpg
# 1093007_tmp_d41d8cd98f00b204e9800998ecf8427e1497list2.jpg
# 1097640_tmp_d41d8cd98f00b204e9800998ecf8427e7190list2.jpg
# 1079497_tmp_d41d8cd98f00b204e9800998ecf8427e9410list2.jpg
# 1220783_tmp_d41d8cd98f00b204e9800998ecf8427e4580list2.jpg
# 1124436_tmp_d41d8cd98f00b204e9800998ecf8427e5630list2.jpg
# 1123010_tmp_d41d8cd98f00b204e9800998ecf8427e3984list2.jpg
# 1033176_tmp_d41d8cd98f00b204e9800998ecf8427e6605list2.jpg
# ...

# %%
from IPython.display import Image, display
import time
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import requests
import os
from urllib.parse import urlparse
import re

options = Options()

options.add_argument("--headless")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
options.add_argument(f"user-agent={user_agent}")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--lang=ko-KR,ko")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

driver = webdriver.Chrome(service=Service("./driver/chromedriver.exe"), options=options)

try:
    url = "https://ant.design/components/overview/"
    driver.get(url)
    time.sleep(1)
    css_selector = ".ant-card-body img"
    img_tags = driver.find_elements(By.CSS_SELECTOR, css_selector)
    for img_tag in img_tags:
        src = img_tag.get_attribute("src")
        img = Image(url=src)
        display(img)
except Exception as e:
    print(e)
finally:
    driver.quit()
